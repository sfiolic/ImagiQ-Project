# %%
import torch
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import torchvision.transforms as transforms

# https://www.cs.virginia.edu/~vicente/recognition/notebooks/image_processing_lab.html

# pytorch provides a function to convert PIL images to tensors.
pil2tensor = transforms.ToTensor()
tensor2pil = transforms.ToPILImage()

# Read the image from file. 

# For the dataset https://www.kaggle.com/nih-chest-xrays/data, I unzipped some on my laptop.

# Here are two ways to visualize these png files. One is to convert it into RGB format.
rgb_pil_image = Image.open(r"E:\archive\images_001\images\00000032_000.png").convert("RGB")
rgb_image = pil2tensor(rgb_pil_image)

# Plot the image here using matplotlib.
def plot_image(tensor):
    plt.figure()
    # imshow needs a numpy array with the channel dimension
    # as the the last dimension so we have to transpose things.
    plt.imshow(tensor.numpy().transpose(1, 2, 0))
    plt.show()

plot_image(rgb_image)

# Show the image tensor type and tensor size here.
print('Image type: ' + str(rgb_image.type()))
print('Image size: ' + str(rgb_image.size()))
# We get channel = 3, height = 1024, width = 1024
# Out:
# Image type: torch.FloatTensor
# Image size: torch.Size([3, 1024, 1024])

# %%
# The second one is to convert it into long grayscale format.
grayscale_pil_image = Image.open(r"E:\archive\images_001\images\00000032_000.png").convert("L")
grayscale_image = pil2tensor(grayscale_pil_image)

def plot_grayscale_image(tensor):
    plt.figure()
    plt.imshow(tensor.numpy().transpose(1, 2, 0), cmap = 'gray')
    plt.show()
    
plot_grayscale_image(grayscale_image)

# Show the image tensor type and tensor size here.
print('Image type: ' + str(grayscale_image.type()))
print('Image size: ' + str(grayscale_image.size()))
# We get channel = 1, height = 1024, width = 1024
# Out:
# Image type: torch.FloatTensor
# Image size: torch.Size([1, 1024, 1024])

# %%
import cv2
import os


# Write the function for uploading all png files in the file folder.
def load_images_from_folder(folder):
    images = []
    for filename in os.listdir(folder):
        img = cv2.imread(os.path.join(folder,filename))
        if img is not None:
            images.append(img)
    return images

folder = r"E:\archive\images_001\images"

# %%
# img = load_images_from_folder(folder)

# %%
# img_tensor = torch.FloatTensor(img)

# %%
# (n, height, width, color_depth) = np.shape(img)

# %% [markdown]
# Then, I select some png files in images_001 as training set and some in images_002 as test set and I am trying to build a naive neural network using pytorch.
